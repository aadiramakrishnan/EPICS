# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Dep_World.csv")

# %%
df.head()
# Out:
#       Entity Code  Year  20-24 years old (%)  10-14 years old (%)  \
# 0  Australia  AUS  1990             6.887634             2.324561
# 1  Australia  AUS  1991             6.970106             2.340434
# 2  Australia  AUS  1992             7.029410             2.359304
# 3  Australia  AUS  1993             7.089476             2.382967
# 4  Australia  AUS  1994             7.129570             2.396370
#
#    All ages (%)  70+ years old (%)  30-34 years old (%)  15-19 years old (%)  \
# 0      4.860523           4.292695             6.021202             5.417275
# 1      4.913392           4.309845             6.071570             5.484133
# 2      4.958442           4.321667             6.120825             5.538638
# 3      4.997909           4.333698             6.164233             5.581052
# 4      5.026350           4.334721             6.200122             5.616769
#
#    25-29 years old (%)  50-69 years old (%)  Age-standardized (%)  \
# 0             6.385726             5.237377              4.621187
# 1             6.450125             5.273631              4.671933
# 2             6.505394             5.300453              4.715412
# 3             6.549972             5.324595              4.754454
# 4             6.583884             5.340639              4.783948
#
#    15-49 years old (%)
# 0             6.059946
# 1             6.122557
# 2             6.174463
# 3             6.219099
# 4             6.255879

# %%
country = df['Entity']
age_15 = df['15-19 years old (%)']

# %%
plt.bar(x=country,
 
        height=age_15)
plt.title('Percentage of 15-19 year old kids showing signs of depression in each region')
# Out:
# Text(0.5, 1.0, 'Percentage of 15-19 year old kids showing signs of depression in each country')

# %%
plt.scatter(country, age_15)
plt.xlabel("Region")
plt.ylabel("15-19 year old")
plt.title('Scatter plot of 15-19 year old kids showing signs of depression in each region')
# Out:
# Text(0.5, 1.0, 'Scatter plot of 15-19 year old kids showing signs of depression in each country')

# %%
age_20 = df['20-24 years old (%)']
age_25 = df['25-29 years old (%)']

# %%
plt.bar(x=country,
 
        height=age_20)
plt.title('Percentage of 20-24 year old kids showing signs of depression in each region')
# Out:
# Text(0.5, 1.0, 'Percentage of 20-24 year old kids showing signs of depression in each country')

# %%
plt.bar(x=country,
 
        height=age_25)
plt.title('Percentage of 25-29 year old kids showing signs of depression in each region')
# Out:
# Text(0.5, 1.0, 'Percentage of 25-29 year old kids showing signs of depression in each country')

# %%
df2 = df[['Entity','10-14 years old (%)','15-19 years old (%)','20-24 years old (%)','25-29 years old (%)','50-69 years old (%)','All ages (%)']]

# %%
df2.head()
# Out:
#       Entity  10-14 years old (%)  15-19 years old (%)  20-24 years old (%)  \
# 0  Australia             2.324561             5.417275             6.887634
# 1  Australia             2.340434             5.484133             6.970106
# 2  Australia             2.359304             5.538638             7.029410
# 3  Australia             2.382967             5.581052             7.089476
# 4  Australia             2.396370             5.616769             7.129570
#
#    25-29 years old (%)  50-69 years old (%)  All ages (%)
# 0             6.385726             5.237377      4.860523
# 1             6.450125             5.273631      4.913392
# 2             6.505394             5.300453      4.958442
# 3             6.549972             5.324595      4.997909
# 4             6.583884             5.340639      5.026350

# %%
plt.bar(x=country,
 
        height=age_15)
# Out:
# <BarContainer object of 168 artists>

# %%
g = sns.pairplot(df2, kind="reg")

# %%
plt.scatter(country, age_20)
plt.xlabel("Region")
plt.ylabel("20-24 year old")
plt.title('Scatter plot of 20-24 year old kids showing signs of depression in each region')
# Out:
# Text(0.5, 1.0, 'Scatter plot of 20-24 year old kids showing signs of depression in each region')

# %%
plt.scatter(country, age_25)
plt.xlabel("Region")
plt.ylabel("25-29 year old")
plt.title('Scatter plot of 25-29 year old kids showing signs of depression in each region')
# Out:
# Text(0.5, 1.0, 'Scatter plot of 25-29 year old kids showing signs of depression in each region')
